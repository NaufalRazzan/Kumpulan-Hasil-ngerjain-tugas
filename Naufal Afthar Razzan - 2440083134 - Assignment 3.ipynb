# %% [markdown]
# Naufal Afthar Razzan - 2440083134 - LB07

# %%
import pandas as pd

df = pd.read_csv('listings2.csv')
df
# Out:
#             id                                               name    host_id  \
# 0        49091                  COZICOMFORT LONG TERM STAY ROOM 2     266763
# 1        50646                    Pleasant Room along Bukit Timah     227796
# 2        56334                                        COZICOMFORT     266763
# 3        71609                Ensuite Room (Room 1 & 2) near EXPO     367042
# 4        71896                    B&B  Room 1 near Airport & EXPO     367042
# ...        ...                                                ...        ...
# 7902  38105126  Loft 2 pax near Haw Par / Pasir Panjang. Free ...  278109833
# 7903  38108273                         3bedroom luxury at Orchard  238891646
# 7904  38109336    [ Farrer Park ] New City Fringe CBD Mins to MRT  281448565
# 7905  38110493          Cheap Master Room in Central of Singapore  243835202
# 7906  38112762  Amazing room with private bathroom walk to Orc...   28788520
#
# ...

# %% [markdown]
# 1). Extracting discrete and continuous random variables

# %%
x = df[['id', 'name', 'host_id', 'host_name', 'neighbourhood_group', 'neighbourhood', 'room_type', 'price', 'minimum_nights', 'number_of_reviews', 'last_review', 'calculated_host_listings_count', 'availability_365']]
y = df[['latitude', 'longitude', 'reviews_per_month']]

# %%
x
# Out:
#             id                                               name    host_id  \
# 0        49091                  COZICOMFORT LONG TERM STAY ROOM 2     266763
# 1        50646                    Pleasant Room along Bukit Timah     227796
# 2        56334                                        COZICOMFORT     266763
# 3        71609                Ensuite Room (Room 1 & 2) near EXPO     367042
# 4        71896                    B&B  Room 1 near Airport & EXPO     367042
# ...        ...                                                ...        ...
# 7902  38105126  Loft 2 pax near Haw Par / Pasir Panjang. Free ...  278109833
# 7903  38108273                         3bedroom luxury at Orchard  238891646
# 7904  38109336    [ Farrer Park ] New City Fringe CBD Mins to MRT  281448565
# 7905  38110493          Cheap Master Room in Central of Singapore  243835202
# 7906  38112762  Amazing room with private bathroom walk to Orc...   28788520
#
# ...

# %%
y
# Out:
#       latitude  longitude  reviews_per_month
# 0      1.44255  103.79580               0.01
# 1      1.33235  103.78521               0.28
# 2      1.44246  103.79667               0.20
# 3      1.34541  103.95712               0.15
# 4      1.34567  103.95963               0.22
# ...        ...        ...                ...
# 7902   1.27973  103.78751                NaN
# 7903   1.29269  103.82623                NaN
# 7904   1.31286  103.85996                NaN
# 7905   1.29543  103.83801                NaN
# 7906   1.29672  103.83325                NaN
#
# [7907 rows x 3 columns]

# %% [markdown]
# 2). Calculated PMF (probability mass function) for discrete random variable

# %%
# variable = room_type

pmf_list = pd.concat([x.room_type.value_counts(normalize = True, ascending = True), x.room_type.value_counts()], axis = 1, keys= ('pmf', 'count'))

pmf_list
# Out:
#                       pmf  count
# Shared room      0.049829    394
# Private room     0.427596   3381
# Entire home/apt  0.522575   4132

# %% [markdown]
# 3). Plot bar chart

# %%
pmf = x.room_type.value_counts(normalize = True, ascending = True)
pmf.plot.bar()
# Out:
# <AxesSubplot:>

# %% [markdown]
# 4). Calculated PDF (probability density function) for continuous random variables

# %%
# variable = longitude

pdf = y.longitude.value_counts(normalize = True, ascending = True)
pdf
# Out:
# 103.79580    0.000126
# 103.78435    0.000126
# 103.91444    0.000126
# 103.88852    0.000126
# 103.73912    0.000126
#                ...
# 103.85192    0.000759
# 103.84360    0.000759
# 103.85361    0.000885
# 103.86022    0.000885
# 103.84294    0.000885
# Name: longitude, Length: 5414, dtype: float64

# %%
pdf_list = pd.concat([pdf, y.longitude.value_counts(ascending = True)], axis = 1, keys = ('pdf', 'count'))
pdf_list
# Out:
#                 pdf  count
# 103.79580  0.000126      1
# 103.78435  0.000126      1
# 103.91444  0.000126      1
# 103.88852  0.000126      1
# 103.73912  0.000126      1
# ...             ...    ...
# 103.85192  0.000759      6
# 103.84360  0.000759      6
# 103.85361  0.000885      7
# 103.86022  0.000885      7
# 103.84294  0.000885      7
#
# [5414 rows x 2 columns]

# %% [markdown]
# 5). Plot Histogram

# %%
pdf_list.hist()
# Out:
# array([[<AxesSubplot:title={'center':'pdf'}>,
#         <AxesSubplot:title={'center':'count'}>]], dtype=object)
